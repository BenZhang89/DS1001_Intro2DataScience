# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
cwd = os.getcwd()
datadir = '/'.join(cwd.split('/')[0:-1]) + '/dataset/'
print(datadir)
# Out:
# /Users/zhangben/Google Drive/NYU/Classes/1001 Introduction to Data Science/dataset/

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==True]
AttriBusiness=BusinessData[filter_col]
#AttriBusiness.head(20).transpose()

# %%
last20=AttriBusiness[AttriBusiness.columns[59:]]
last20.head(20).transpose()
# Out:
#                                              0      1      2    3      4   \
# attributes.HairSpecializesIn.extensions     NaN    NaN    NaN  NaN    NaN
# attributes.BestNights.saturday              NaN    NaN    NaN  NaN    NaN
# attributes.Ambience.casual                  NaN  False    NaN  NaN  False
# attributes.BestNights.thursday              NaN    NaN    NaN  NaN    NaN
# attributes.BestNights.monday                NaN    NaN    NaN  NaN    NaN
# attributes.HairSpecializesIn.asian          NaN    NaN    NaN  NaN    NaN
# attributes.DietaryRestrictions.kosher       NaN    NaN    NaN  NaN    NaN
# attributes.WiFi                             NaN    NaN     no  NaN     no
# attributes.Smoking                          NaN    NaN    NaN  NaN    NaN
# attributes.DietaryRestrictions.halal        NaN    NaN    NaN  NaN    NaN
# attributes.GoodForDancing                   NaN    NaN    NaN  NaN    NaN
# attributes.ByAppointmentOnly                NaN    NaN    NaN  NaN    NaN
# ...

# %%
print(last20.shape)
for column in last20.columns:
    print(last20[column].value_counts(sort=False,dropna=False))
# Out:
# (156639, 22)
# NaN      155234
# False       570
# True        835
# Name: attributes.HairSpecializesIn.extensions, dtype: int64
# NaN      150248
# False      1726
# True       4665
# Name: attributes.BestNights.saturday, dtype: int64
# NaN      113739
# False     23956
# True      18944
# Name: attributes.Ambience.casual, dtype: int64
# NaN      150248
# False      3841
# True       2550
# Name: attributes.BestNights.thursday, dtype: int64
# NaN      150248
# False      5698
# True        693
# Name: attributes.BestNights.monday, dtype: int64
# NaN      155465
# False       598
# True        576
# Name: attributes.HairSpecializesIn.asian, dtype: int64
# NaN      156390
# False       245
# True          4
# Name: attributes.DietaryRestrictions.kosher, dtype: int64
# NaN     113210
# paid       543
# free     20929
# no       21957
# Name: attributes.WiFi, dtype: int64
# NaN        148966
# yes          1140
# no           3019
# outdoor      3514
# ...

# %% [markdown]
# 60.attributes.HairSpecializesIn.extensions------No
# 61.attributes.BestNights.saturday-----------Yes,can be combined with BestNights.Monday....
# 62.attributes.Ambience.casual-----------Yes,combined with other ambience
# 63.attributes.BestNights.thursday-----------Yes,Same as 60
# 64.attributes.BestNights.monday----------Yes,Same as 60
# 65.attributes.HairSpecializesIn.asian-------No
# 66.attributes.DietaryRestrictions.kosher-----Yes
# 67.attributes.WiFi--------------Yes
# 68.attributes.Smoking------------Yes
# 69.attributes.DietaryRestrictions.halal--------Yes
# 70.attributes.GoodForDancing---------Yes
# 71.attributes.ByAppointmentOnly--------No(probabily for dentist, haircuts,etc.)
# 72.attributes.Caters-----------Yes(自助餐？）
# 73.attributes.RestaurantsReservations-----Yes
# 74.attributes.DietaryRestrictions.dairy-free---------Yes
# 75.attributes.DietaryRestrictions.vegan---------Yes
# 76.attributes.Ambience.romantic----Yes
# 77.attributes.Music.jukebox----Yes,点唱机
# 78.attributes.Ambience.upscale-----Yes
# 79.attributes.RestaurantsTakeOut----Yes
# 80.attributes.BikeParking-----Yes
# 81.attributes.OutdoorSeating----Yes

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==False]
NAttriBusiness=BusinessData[filter_col]
cols=['business_id', 'name','stars','is_open','state','city','address','postal_code','neighborhood','latitude'
                              ,'longitude','categories','hours.Monday','hours.Tuesday','hours.Wednesday','hours.Thursday','hours.Friday',
                              'hours.Saturday','hours.Sunday']

Rearrange=NAttriBusiness[cols]
Rearrange.head(20).transpose()
# Out:
#                                                0   \
# business_id                YDf95gJZaq05wvo7hTQbbQ
# name                         Richmond Town Square
# stars                                           2
# is_open                                         1
# state                                          OH
# city                             Richmond Heights
# address                           691 Richmond Rd
# postal_code                                 44143
# neighborhood                                  NaN
# latitude                                  41.5417
# longitude                                -81.4931
# categories       ['Shopping', 'Shopping Centers']
# hours.Monday                          10:00-21:00
# hours.Tuesday                         10:00-21:00
# hours.Wednesday                       10:00-21:00
# hours.Thursday                        10:00-21:00
# hours.Friday                          10:00-21:00
# hours.Saturday                        10:00-21:00
# ...

# %%
len(Rearrange["hours.Monday"])
# Out:
# 156639

# %%
Rearrange["Mondayhours"]=np.nan

# %%
Rearrange["Tuesdayhours"]=np.nan
Rearrange["Wednesdayhours"]=np.nan
Rearrange["Thursdayhours"]=np.nan
Rearrange["Fridayhours"]=np.nan
Rearrange["Saturdayhours"]=np.nan
Rearrange["Sundayhours"]=np.nan

# %%
#Rearrange["hours.Monday"]
import re
for i in range(10000):
    if Rearrange["hours.Monday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Monday"][i])
        Rearrange["Mondayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
#len(Rearrange["hours.Tuesday"])
for i in range(1000):
    if Rearrange["hours.Tuesday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Tuesday"][i])
        Rearrange["Tuesdayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
#len(Rearrange["hours.Wednesday"])
for i in range(1000):
    if Rearrange["hours.Wednesday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Wednesday"][i])
        Rearrange["Wednesdayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
#len(Rearrange["hours.Thursday"])
for i in range(1000):
    if Rearrange["hours.Thursday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Thursday"][i])
        Rearrange["Thursdayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
#len(Rearrange["hours.Friday"])
for i in range(1000):
    if Rearrange["hours.Friday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Friday"][i])
        Rearrange["Fridayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
#len(Rearrange["hours.Saturday"])
for i in range(1000):
    if Rearrange["hours.Saturday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Saturday"][i])
        Rearrange["Saturdayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
#len(Rearrange["hours.Sunday"])
for i in range(1000):
    if Rearrange["hours.Sunday"].isnull()[i]==False:
        x=re.split(':|-',Rearrange["hours.Sunday"][i])
        Rearrange["Sundayhours"][i]=int(x[2])-int(x[0])
Rearrange.head(20)
# Out:
# C:\Users\ZXY\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                business_id                                name  stars  \
# 0   YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square    2.0
# 1   mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs    4.5
# 2   v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    4.5
# 3   CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch    3.0
# 4   duHFBe87uNSXImQmvBh87Q                             Blimpie    4.5
# 5   uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars    5.0
# 6   2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic    5.0
# 7   fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse    2.5
# ...

# %%
Rearrange.to_csv("1001ProjectWhours.csv")

# %%
Rearrange=pd.read_csv("1001ProjectWhours.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 1: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-44f350e360d1> in <module>()
# ----> 1 Rearrange=pd.read_csv("1001ProjectWhours.csv")
#
# ...

# %%
Rearrange["hours.Monday"].isnull()[4]
# Out:
# True

# %%
import re
print (re.split(':|-',Rearrange["hours.Monday"][0]))
# Out:
# ['10', '00', '21', '00']
