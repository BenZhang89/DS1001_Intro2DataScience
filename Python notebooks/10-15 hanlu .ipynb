# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
cwd = os.getcwd()
datadir ='/'.join(cwd.split('/')[0:-1]) + '/project/'

BusinessData = pd.read_csv(datadir+'business.csv')

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==True]
AttriBusiness=BusinessData[filter_col]

# %%
from collections import Counter
AttriBusiness.apply(lambda x: Counter(x))[20:40]
#Counter(AttriBusiness['attributes.RestaurantsAttire'])
# Out:
# attributes.DietaryRestrictions.vegetarian                  {nan: 156390, False: 177, True: 72}
# attributes.Music.live                                   {nan: 148612, False: 6622, True: 1405}
# attributes.Music.background_music                       {nan: 148612, False: 6194, True: 1833}
# attributes.BusinessParking.lot                         {True: 34972, nan: 67200, False: 54467}
# attributes.Music.karaoke                                 {nan: 148612, False: 7786, True: 241}
# attributes.GoodForMeal.breakfast                       {nan: 113687, False: 39225, True: 3727}
# attributes.NoiseLevel                        {nan: 115986, 'average': 26126, 'quiet': 8949,...
# attributes.HairSpecializesIn.perms                        {nan: 155234, False: 745, True: 660}
# attributes.DriveThru                                    {nan: 150599, False: 3687, True: 2353}
# attributes.HasTV                                      {nan: 112911, False: 21119, True: 22609}
# ...

# %%
BusinessData[BusinessData['categories'].str.contains('Food|Restaurants', case = False)]
# Out:
#        attributes.Ambience.divey attributes.RestaurantsDelivery  \
# 1                          False                           True
# 2                            NaN                            NaN
# 4                          False                          False
# 12                           NaN                          False
# 14                         False                          False
# 15                           NaN                            NaN
# 18                           NaN                          False
# 21                          True                          False
# 22                           NaN                          False
# 31                         False                          False
# 32                           NaN                          False
# 34                           NaN                          False
# 35                           NaN                          False
# 36                         False                          False
# ...
