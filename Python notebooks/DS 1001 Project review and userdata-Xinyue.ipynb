# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datadir = "E:/DS1001Project/dataset/"

ReviewData = pd.read_csv(datadir+'review.csv')

# %%
print("Column Names Are:")
print("")

for column_name in ReviewData.columns.values:
    print(column_name)

print("")
print('Total # of Columns = {}'.format(len(ReviewData.columns)))
# Out:
# Column Names Are:
#
# funny
# user_id
# review_id
# text
# business_id
# stars
# date
# useful
# cool
#
# Total # of Columns = 9

# %%
ReviewData.head(20).transpose()
# Out:
#                                                             0   \
# funny                                                        0
# user_id                                 cjpdDjZyprfyDG3RlkVG3w
# review_id                               VfBHSwC5Vz_pbFluy07i9Q
# text         My girlfriend and I stayed here for 3 nights a...
# business_id                             uYHaNptLzDLoV_JZ_MuzUA
# stars                                                        5
# date                                                2016-07-12
# useful                                                       0
# cool                                                         0
#
#                                                             1   \
# funny                                                        0
# user_id                                 bjTcT8Ty4cJZhEOEo01FGA
# review_id                               3zRpneRKDsOPq92tq7ybAA
# text         If you need an inexpensive place to stay for a...
# ...

# %%
plt.figure()
hist_inc = ReviewData['useful'].hist(range=[0, 15])
plt.title('Histogram of useful counts')
plt.show()

# %%
datadir = "E:/DS1001Project/dataset/"

UserData = pd.read_csv(datadir+'user.csv')

# %%
print("Column Names Are:")
print("")

for column_name in UserData.columns.values:
    print(column_name)

print("")
print('Total # of Columns = {}'.format(len(UserData.columns)))
# Out:
# Column Names Are:
#
# yelping_since
# useful
# compliment_photos
# compliment_list
# compliment_funny
# compliment_plain
# review_count
# elite
# fans
# compliment_note
# funny
# compliment_writer
# compliment_cute
# average_stars
# user_id
# compliment_more
# friends
# compliment_hot
# cool
# name
# compliment_profile
# compliment_cool
#
# Total # of Columns = 22

# %%
UserData.head(20).transpose()
# Out:
#                                                                    0   \
# yelping_since                                              2010-07-13
# useful                                                          17019
# compliment_photos                                                7829
# compliment_list                                                    78
# compliment_funny                                                 5174
# compliment_plain                                                 7397
# review_count                                                      272
# elite                [2014, 2016, 2013, 2011, 2012, 2015, 2010, 2017]
# fans                                                              209
# compliment_note                                                  1435
# funny                                                           16605
# compliment_writer                                                1834
# ...

# %%
plt.figure()
hist_inc = UserData['review_count'].hist(range=[0,100])
plt.title('Histogram of review counts')
plt.show()

# %%
plt.figure()
hist_inc = UserData['average_stars'].hist()
plt.title('Histogram of avarage stars')
plt.show()

# %%
plt.figure()
hist_inc = UserData['fans'].hist(range=[0,20])
plt.title('Histogram of fan number')
plt.show()
