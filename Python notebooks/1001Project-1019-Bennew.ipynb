# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
cwd = os.getcwd()
datadir = '/'.join(cwd.split('/')[0:-1]) + '/Yelpdataset/'
BusinessData = pd.read_csv(datadir+'business.csv')

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==True]
AttriBusiness=BusinessData[filter_col]
#AttriBusiness.head(20).transpose()

# %%
first20=AttriBusiness[AttriBusiness.columns[0:20]]
first20.head(20).transpose()
# Out:
#                                          0      1     2    3      4     5   \
# attributes.Ambience.divey               NaN  False   NaN  NaN  False   NaN
# attributes.RestaurantsDelivery          NaN   True   NaN  NaN  False   NaN
# attributes.DogsAllowed                  NaN    NaN   NaN  NaN    NaN   NaN
# attributes.HairSpecializesIn.coloring   NaN    NaN   NaN  NaN    NaN   NaN
# attributes.BestNights.sunday            NaN    NaN   NaN  NaN    NaN   NaN
# attributes.BYOB                         NaN    NaN   NaN  NaN    NaN   NaN
# attributes.AgesAllowed                  NaN    NaN   NaN  NaN    NaN   NaN
# attributes.Music.video                  NaN    NaN   NaN  NaN    NaN   NaN
# attributes.Alcohol                      NaN    NaN   NaN  NaN   none   NaN
# attributes.Ambience.classy              NaN  False   NaN  NaN  False   NaN
# attributes.RestaurantsTableService      NaN    NaN   NaN  NaN  False   NaN
# ...

# %%
print(first20.shape)
for column in first20.columns:
    print(first20[column].value_counts(sort=False,dropna=False))
# Out:
# (156639, 20)
# NaN      129461
# False     26067
# True       1111
# Name: attributes.Ambience.divey, dtype: int64
# NaN      109836
# False     35535
# True      11268
# Name: attributes.RestaurantsDelivery, dtype: int64
# NaN      145425
# False      7646
# True       3568
# Name: attributes.DogsAllowed, dtype: int64
# NaN      155234
# False       279
# True       1126
# Name: attributes.HairSpecializesIn.coloring, dtype: int64
# NaN      150248
# False      5113
# True       1278
# Name: attributes.BestNights.sunday, dtype: int64
# NaN      155734
# False       857
# True         48
# Name: attributes.BYOB, dtype: int64
# NaN        156244
# 18plus         86
# 19plus         63
# 21plus        211
# allages        35
# Name: attributes.AgesAllowed, dtype: int64
# NaN      148612
# False      7820
# True        207
# Name: attributes.Music.video, dtype: int64
# NaN              112399
# beer_and_wine      6446
# none              19025
# full_bar          18769
# ...

# %% [markdown]
# 0.attributes.Ambience.divey------Yes,ambience is important for customers
# 1.attributes.RestaurantsDelivery-----------Yes,delivery is an important part for restaurant
# 2.attributes.DogsAllowed-----------To be discussed; not very important, and lacks data
# 3.attributes.HairSpecializesIn.coloring-----------No
# 4.attributes.BestNights.sunday----------To be discussed; important, but lacks data
# 5.attributes.BYOB-------No,自带酒水，lacks data
# 6.attributes.AgesAllowed-----Yes
# 7.attributes.Music.video--------------Yes
# 8.attributes.Alcohol------------Yes
# 9.attributes.Ambience.classy--------Yes，ambience is important for customers
# 10.attributes.RestaurantsTableService---------Yes
# 11.attributes.Ambience.touristy--------Yes,ambience is important for customers,but lacks data. combine with other ambience
# 12.attributes.RestaurantsCounterService-----------To be discussed; not very important, and lacks data
# 13.attributes.Corkage-----Yes
# 14.attributes.RestaurantsGoodForGroups---------Yes
# 15.attributes.BusinessAcceptsBitcoin---------No, no pratical for restaurant now.
# 16.attributes.HappyHour----Yes
# 17.attributes.WheelchairAccessible----Yes
# 18.attributes.Ambience.hipster-----Yes
# 19.BusinessAcceptsCreditCards----Yes,important

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==False]
NAttriBusiness=BusinessData[filter_col]
cols=['business_id', 'name','stars','is_open','state','city','address','postal_code','neighborhood','latitude'
                              ,'longitude','categories','hours.Monday','hours.Tuesday','hours.Wednesday','hours.Thursday','hours.Friday',
                              'hours.Saturday','hours.Sunday']

Rearrange=NAttriBusiness[cols]
Rearrange.head(20).transpose()
# Out:
#                                                0   \
# business_id                YDf95gJZaq05wvo7hTQbbQ
# name                         Richmond Town Square
# stars                                           2
# is_open                                         1
# state                                          OH
# city                             Richmond Heights
# address                           691 Richmond Rd
# postal_code                                 44143
# neighborhood                                  NaN
# latitude                                  41.5417
# longitude                                -81.4931
# categories       ['Shopping', 'Shopping Centers']
# hours.Monday                          10:00-21:00
# hours.Tuesday                         10:00-21:00
# hours.Wednesday                       10:00-21:00
# hours.Thursday                        10:00-21:00
# hours.Friday                          10:00-21:00
# hours.Saturday                        10:00-21:00
# ...

# %%
len(Rearrange["state"])
# Out:
# 156639

# %%
print(Rearrange["state"])
# Out:
# 0          OH
# 1          NC
# 2          ON
# 3          AZ
# 4          AZ
# 5          AZ
# 6          AZ
# 7          PA
# 8          PA
# 9          AZ
# 10         NV
# 11         AZ
# 12         AZ
# 13         AZ
# 14         NC
# 15         NC
# 16         AZ
# 17         OH
# 18         OH
# 19         NV
# 20         NC
# 21         PA
# 22         ON
# 23         AZ
# 24         AZ
# 25        EDH
# 26         ON
# 27         QC
# 28         PA
# 29         AZ
#          ...
# 156609     AZ
# 156610     NV
# 156611     NV
# 156612     AZ
# 156613     ON
# 156614     QC
# 156615     NV
# 156616     NV
# 156617     ON
# 156618     QC
# 156619     AZ
# 156620     NV
# 156621     AZ
# 156622     NV
# 156623     NV
# 156624     AZ
# 156625     NC
# 156626     PA
# 156627     AZ
# 156628     AZ
# 156629     AZ
# 156630     ON
# 156631     QC
# 156632     ON
# 156633     NC
# 156634     ON
# 156635     NV
# 156636     AZ
# 156637    HLD
# 156638     NV
# ...

# %%
list_states=['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD'
             ,'MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC',
             'SD','TN','TX','UT','VT','VA','WA','WV','WI','WY','AS','DC','FM','GU','MH','MP','PW','PR','VI']
len(list_states)
# Out:
# 59

# %%
df[Rearrange["state"].isin([3, 6])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-6b2a2287dc80> in <module>()
#       6             newdf = concat([df[df[colName] == record], newdf], ignore_index=True)
#       7     return newdf
# ----> 8 test=stringSearchColumn_DataFrame(Rearrange, Rearrange["state"],list_states)
#       9 test.head(20)
#
# <ipython-input-37-6b2a2287dc80> in stringSearchColumn_DataFrame(df, colName, regex)
#       1 def stringSearchColumn_DataFrame(df, colName, regex):
#       2     newdf = df
# ----> 3     for idx, record in df[colName].iteritems():
#       4
#       5         if re.search(regex, record):
#
# /Users/zhangben/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# ...
