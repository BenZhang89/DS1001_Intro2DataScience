# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datadir = "E:/DS1001Project/dataset/"

BusinessData = pd.read_csv(datadir+'business.csv')

# %%
print("Column Names Are:")
print("")

for column_name in BusinessData.columns.values:
    print(column_name)

print("")
print('Total # of Columns = {}'.format(len(BusinessData.columns)))
# Out:
# Column Names Are:
#
# attributes.Ambience.divey
# attributes.RestaurantsDelivery
# attributes.DogsAllowed
# postal_code
# hours.Thursday
# attributes.HairSpecializesIn.coloring
# attributes.BestNights.sunday
# attributes.BYOB
# attributes.AgesAllowed
# attributes.Music.video
# hours.Friday
# latitude
# attributes.Alcohol
# attributes.Ambience.classy
# attributes.RestaurantsTableService
# business_id
# attributes.Ambience.touristy
# attributes.RestaurantsCounterService
# attributes.Corkage
# attributes.RestaurantsGoodForGroups
# categories
# name
# attributes.BusinessAcceptsBitcoin
# attributes.HappyHour
# attributes.WheelchairAccessible
# attributes.Ambience.hipster
# attributes.BusinessAcceptsCreditCards
# is_open
# attributes.DietaryRestrictions.vegetarian
# attributes.Music.live
# attributes.Music.background_music
# neighborhood
# attributes.BusinessParking.lot
# attributes.Music.karaoke
# review_count
# attributes.GoodForMeal.breakfast
# attributes.NoiseLevel
# attributes.HairSpecializesIn.perms
# state
# attributes.DriveThru
# attributes.HasTV
# attributes.GoodForMeal.dinner
# attributes.BusinessParking.street
# address
# attributes.RestaurantsAttire
# hours.Sunday
# attributes.BestNights.tuesday
# attributes.AcceptsInsurance
# attributes.BestNights.wednesday
# hours.Wednesday
# attributes.HairSpecializesIn.kids
# attributes.Open24Hours
# attributes.Ambience.trendy
# attributes.CoatCheck
# hours.Monday
# attributes.HairSpecializesIn.straightperms
# city
# attributes.HairSpecializesIn.curly
# attributes.Music.no_music
# hours.Tuesday
# attributes.HairSpecializesIn.africanamerican
# stars
# attributes.RestaurantsPriceRange2
# attributes.Ambience.intimate
# attributes.GoodForMeal.latenight
# attributes.GoodForMeal.dessert
# attributes.BusinessParking.validated
# attributes.GoodForMeal.lunch
# attributes.GoodForKids
# attributes.DietaryRestrictions.soy-free
# attributes.GoodForMeal.brunch
# attributes.BusinessParking.valet
# longitude
# attributes.DietaryRestrictions.gluten-free
# attributes.BYOBCorkage
# attributes.BusinessParking.garage
# attributes.BestNights.friday
# hours.Saturday
# attributes.Music.dj
# attributes.HairSpecializesIn.extensions
# attributes.BestNights.saturday
# attributes.Ambience.casual
# attributes.BestNights.thursday
# attributes.BestNights.monday
# attributes.HairSpecializesIn.asian
# attributes.DietaryRestrictions.kosher
# attributes.WiFi
# attributes.Smoking
# attributes.DietaryRestrictions.halal
# attributes.GoodForDancing
# attributes.ByAppointmentOnly
# attributes.Caters
# attributes.RestaurantsReservations
# attributes.DietaryRestrictions.dairy-free
# attributes.DietaryRestrictions.vegan
# attributes.Ambience.romantic
# attributes.Music.jukebox
# attributes.Ambience.upscale
# attributes.RestaurantsTakeOut
# attributes.BikeParking
# attributes.OutdoorSeating
#
# Total # of Columns = 101

# %%
BusinessData.head().transpose()
# Out:
#                                                                            0  \
# attributes.Ambience.divey                                                NaN
# attributes.RestaurantsDelivery                                           NaN
# attributes.DogsAllowed                                                   NaN
# postal_code                                                            44143
# hours.Thursday                                                   10:00-21:00
# attributes.HairSpecializesIn.coloring                                    NaN
# attributes.BestNights.sunday                                             NaN
# attributes.BYOB                                                          NaN
# attributes.AgesAllowed                                                   NaN
# attributes.Music.video                                                   NaN
# hours.Friday                                                     10:00-21:00
# latitude                                                             41.5417
# attributes.Alcohol                                                       NaN
# attributes.Ambience.classy                                               NaN
# attributes.RestaurantsTableService                                       NaN
# business_id                                           YDf95gJZaq05wvo7hTQbbQ
# attributes.Ambience.touristy                                             NaN
# attributes.RestaurantsCounterService                                     NaN
# attributes.Corkage                                                       NaN
# attributes.RestaurantsGoodForGroups                                      NaN
# categories                                  ['Shopping', 'Shopping Centers']
# name                                                    Richmond Town Square
# attributes.BusinessAcceptsBitcoin                                        NaN
# attributes.HappyHour                                                     NaN
# attributes.WheelchairAccessible                                         True
# attributes.Ambience.hipster                                              NaN
# attributes.BusinessAcceptsCreditCards                                    NaN
# is_open                                                                    1
# attributes.DietaryRestrictions.vegetarian                                NaN
# attributes.Music.live                                                    NaN
# ...                                                                      ...
# attributes.BusinessParking.valet                                       False
# longitude                                                           -81.4931
# attributes.DietaryRestrictions.gluten-free                               NaN
# attributes.BYOBCorkage                                                   NaN
# attributes.BusinessParking.garage                                      False
# attributes.BestNights.friday                                             NaN
# hours.Saturday                                                   10:00-21:00
# attributes.Music.dj                                                      NaN
# attributes.HairSpecializesIn.extensions                                  NaN
# attributes.BestNights.saturday                                           NaN
# attributes.Ambience.casual                                               NaN
# attributes.BestNights.thursday                                           NaN
# attributes.BestNights.monday                                             NaN
# attributes.HairSpecializesIn.asian                                       NaN
# attributes.DietaryRestrictions.kosher                                    NaN
# attributes.WiFi                                                          NaN
# attributes.Smoking                                                       NaN
# attributes.DietaryRestrictions.halal                                     NaN
# attributes.GoodForDancing                                                NaN
# attributes.ByAppointmentOnly                                             NaN
# attributes.Caters                                                        NaN
# attributes.RestaurantsReservations                                       NaN
# attributes.DietaryRestrictions.dairy-free                                NaN
# attributes.DietaryRestrictions.vegan                                     NaN
# attributes.Ambience.romantic                                             NaN
# attributes.Music.jukebox                                                 NaN
# attributes.Ambience.upscale                                              NaN
# attributes.RestaurantsTakeOut                                            NaN
# attributes.BikeParking                                                  True
# attributes.OutdoorSeating                                                NaN
#
#                                                                                             1  \
# attributes.Ambience.divey                                                               False
# attributes.RestaurantsDelivery                                                           True
# attributes.DogsAllowed                                                                    NaN
# postal_code                                                                             28215
# hours.Thursday                                                                    10:00-22:00
# attributes.HairSpecializesIn.coloring                                                     NaN
# attributes.BestNights.sunday                                                              NaN
# attributes.BYOB                                                                           NaN
# attributes.AgesAllowed                                                                    NaN
# attributes.Music.video                                                                    NaN
# hours.Friday                                                                      10:00-22:00
# latitude                                                                              35.2369
# attributes.Alcohol                                                                        NaN
# attributes.Ambience.classy                                                              False
# attributes.RestaurantsTableService                                                        NaN
# business_id                                                            mLwM-h2YhXl2NCgdS84_Bw
# attributes.Ambience.touristy                                                            False
# attributes.RestaurantsCounterService                                                      NaN
# attributes.Corkage                                                                        NaN
# attributes.RestaurantsGoodForGroups                                                      True
# categories                                  ['Food', 'Soul Food', 'Convenience Stores', 'R...
# name                                                       South Florida Style Chicken & Ribs
# attributes.BusinessAcceptsBitcoin                                                         NaN
# attributes.HappyHour                                                                      NaN
# attributes.WheelchairAccessible                                                           NaN
# attributes.Ambience.hipster                                                             False
# attributes.BusinessAcceptsCreditCards                                                   False
# is_open                                                                                     0
# attributes.DietaryRestrictions.vegetarian                                                 NaN
# attributes.Music.live                                                                     NaN
# ...                                                                                       ...
# attributes.BusinessParking.valet                                                          NaN
# longitude                                                                             -80.742
# attributes.DietaryRestrictions.gluten-free                                                NaN
# attributes.BYOBCorkage                                                                    NaN
# attributes.BusinessParking.garage                                                         NaN
# attributes.BestNights.friday                                                              NaN
# hours.Saturday                                                                    10:00-22:00
# attributes.Music.dj                                                                       NaN
# attributes.HairSpecializesIn.extensions                                                   NaN
# attributes.BestNights.saturday                                                            NaN
# attributes.Ambience.casual                                                              False
# attributes.BestNights.thursday                                                            NaN
# attributes.BestNights.monday                                                              NaN
# attributes.HairSpecializesIn.asian                                                        NaN
# attributes.DietaryRestrictions.kosher                                                     NaN
# attributes.WiFi                                                                           NaN
# attributes.Smoking                                                                        NaN
# attributes.DietaryRestrictions.halal                                                      NaN
# attributes.GoodForDancing                                                                 NaN
# attributes.ByAppointmentOnly                                                              NaN
# attributes.Caters                                                                         NaN
# attributes.RestaurantsReservations                                                      False
# attributes.DietaryRestrictions.dairy-free                                                 NaN
# attributes.DietaryRestrictions.vegan                                                      NaN
# attributes.Ambience.romantic                                                            False
# attributes.Music.jukebox                                                                  NaN
# attributes.Ambience.upscale                                                             False
# attributes.RestaurantsTakeOut                                                            True
# attributes.BikeParking                                                                    NaN
# attributes.OutdoorSeating                                                               False
#
#                                                                    2  \
# attributes.Ambience.divey                                        NaN
# attributes.RestaurantsDelivery                                   NaN
# attributes.DogsAllowed                                           NaN
# postal_code                                                  M4K 1N7
# hours.Thursday                                           10:00-19:00
# attributes.HairSpecializesIn.coloring                            NaN
# attributes.BestNights.sunday                                     NaN
# attributes.BYOB                                                  NaN
# attributes.AgesAllowed                                           NaN
# attributes.Music.video                                           NaN
# hours.Friday                                             10:00-19:00
# latitude                                                     43.6771
# attributes.Alcohol                                               NaN
# attributes.Ambience.classy                                       NaN
# attributes.RestaurantsTableService                               NaN
# business_id                                   v2WhjAB3PIBA8J8VxG3wEg
# attributes.Ambience.touristy                                     NaN
# attributes.RestaurantsCounterService                             NaN
# attributes.Corkage                                               NaN
# attributes.RestaurantsGoodForGroups                              NaN
# categories                                  ['Food', 'Coffee & Tea']
# name                                                The Tea Emporium
# attributes.BusinessAcceptsBitcoin                                NaN
# attributes.HappyHour                                             NaN
# attributes.WheelchairAccessible                                 True
# attributes.Ambience.hipster                                      NaN
# attributes.BusinessAcceptsCreditCards                           True
# is_open                                                            0
# attributes.DietaryRestrictions.vegetarian                        NaN
# attributes.Music.live                                            NaN
# ...                                                              ...
# attributes.BusinessParking.valet                               False
# longitude                                                   -79.3533
# attributes.DietaryRestrictions.gluten-free                       NaN
# attributes.BYOBCorkage                                           NaN
# attributes.BusinessParking.garage                              False
# attributes.BestNights.friday                                     NaN
# hours.Saturday                                           10:00-18:00
# attributes.Music.dj                                              NaN
# attributes.HairSpecializesIn.extensions                          NaN
# attributes.BestNights.saturday                                   NaN
# attributes.Ambience.casual                                       NaN
# attributes.BestNights.thursday                                   NaN
# attributes.BestNights.monday                                     NaN
# attributes.HairSpecializesIn.asian                               NaN
# attributes.DietaryRestrictions.kosher                            NaN
# attributes.WiFi                                                   no
# attributes.Smoking                                               NaN
# attributes.DietaryRestrictions.halal                             NaN
# attributes.GoodForDancing                                        NaN
# attributes.ByAppointmentOnly                                     NaN
# attributes.Caters                                                NaN
# attributes.RestaurantsReservations                               NaN
# attributes.DietaryRestrictions.dairy-free                        NaN
# attributes.DietaryRestrictions.vegan                             NaN
# attributes.Ambience.romantic                                     NaN
# attributes.Music.jukebox                                         NaN
# attributes.Ambience.upscale                                      NaN
# attributes.RestaurantsTakeOut                                    NaN
# attributes.BikeParking                                          True
# attributes.OutdoorSeating                                      False
#
#                                                                                    3  \
# attributes.Ambience.divey                                                        NaN
# attributes.RestaurantsDelivery                                                   NaN
# attributes.DogsAllowed                                                           NaN
# postal_code                                                                    85258
# hours.Thursday                                                            9:00-17:00
# attributes.HairSpecializesIn.coloring                                            NaN
# attributes.BestNights.sunday                                                     NaN
# attributes.BYOB                                                                  NaN
# attributes.AgesAllowed                                                           NaN
# attributes.Music.video                                                           NaN
# hours.Friday                                                              9:00-17:00
# latitude                                                                     33.5651
# attributes.Alcohol                                                               NaN
# attributes.Ambience.classy                                                       NaN
# attributes.RestaurantsTableService                                               NaN
# business_id                                                   CVtCbSB1zUcUWg-9TNGTuQ
# attributes.Ambience.touristy                                                     NaN
# attributes.RestaurantsCounterService                                             NaN
# attributes.Corkage                                                               NaN
# attributes.RestaurantsGoodForGroups                                              NaN
# categories                                  ['Professional Services', 'Matchmakers']
# name                                                                        TRUmatch
# attributes.BusinessAcceptsBitcoin                                                NaN
# attributes.HappyHour                                                             NaN
# attributes.WheelchairAccessible                                                  NaN
# attributes.Ambience.hipster                                                      NaN
# attributes.BusinessAcceptsCreditCards                                            NaN
# is_open                                                                            1
# attributes.DietaryRestrictions.vegetarian                                        NaN
# attributes.Music.live                                                            NaN
# ...                                                                              ...
# attributes.BusinessParking.valet                                                 NaN
# longitude                                                                   -111.916
# attributes.DietaryRestrictions.gluten-free                                       NaN
# attributes.BYOBCorkage                                                           NaN
# attributes.BusinessParking.garage                                                NaN
# attributes.BestNights.friday                                                     NaN
# hours.Saturday                                                                   NaN
# attributes.Music.dj                                                              NaN
# attributes.HairSpecializesIn.extensions                                          NaN
# attributes.BestNights.saturday                                                   NaN
# attributes.Ambience.casual                                                       NaN
# attributes.BestNights.thursday                                                   NaN
# attributes.BestNights.monday                                                     NaN
# attributes.HairSpecializesIn.asian                                               NaN
# attributes.DietaryRestrictions.kosher                                            NaN
# attributes.WiFi                                                                  NaN
# attributes.Smoking                                                               NaN
# attributes.DietaryRestrictions.halal                                             NaN
# attributes.GoodForDancing                                                        NaN
# attributes.ByAppointmentOnly                                                     NaN
# attributes.Caters                                                                NaN
# attributes.RestaurantsReservations                                               NaN
# attributes.DietaryRestrictions.dairy-free                                        NaN
# attributes.DietaryRestrictions.vegan                                             NaN
# attributes.Ambience.romantic                                                     NaN
# attributes.Music.jukebox                                                         NaN
# attributes.Ambience.upscale                                                      NaN
# attributes.RestaurantsTakeOut                                                    NaN
# attributes.BikeParking                                                           NaN
# attributes.OutdoorSeating                                                        NaN
#
#                                                                         4
# attributes.Ambience.divey                                           False
# attributes.RestaurantsDelivery                                      False
# attributes.DogsAllowed                                                NaN
# postal_code                                                         85016
# hours.Thursday                                                        NaN
# attributes.HairSpecializesIn.coloring                                 NaN
# attributes.BestNights.sunday                                          NaN
# attributes.BYOB                                                       NaN
# attributes.AgesAllowed                                                NaN
# attributes.Music.video                                                NaN
# hours.Friday                                                          NaN
# latitude                                                          33.5059
# attributes.Alcohol                                                   none
# attributes.Ambience.classy                                          False
# attributes.RestaurantsTableService                                  False
# business_id                                        duHFBe87uNSXImQmvBh87Q
# attributes.Ambience.touristy                                        False
# attributes.RestaurantsCounterService                                  NaN
# attributes.Corkage                                                    NaN
# attributes.RestaurantsGoodForGroups                                  True
# categories                                  ['Sandwiches', 'Restaurants']
# name                                                              Blimpie
# attributes.BusinessAcceptsBitcoin                                     NaN
# attributes.HappyHour                                                  NaN
# attributes.WheelchairAccessible                                       NaN
# attributes.Ambience.hipster                                         False
# attributes.BusinessAcceptsCreditCards                                True
# is_open                                                                 0
# attributes.DietaryRestrictions.vegetarian                             NaN
# attributes.Music.live                                                 NaN
# ...                                                                   ...
# attributes.BusinessParking.valet                                    False
# longitude                                                        -112.039
# attributes.DietaryRestrictions.gluten-free                            NaN
# attributes.BYOBCorkage                                                NaN
# attributes.BusinessParking.garage                                   False
# attributes.BestNights.friday                                          NaN
# hours.Saturday                                                        NaN
# attributes.Music.dj                                                   NaN
# attributes.HairSpecializesIn.extensions                               NaN
# attributes.BestNights.saturday                                        NaN
# attributes.Ambience.casual                                          False
# attributes.BestNights.thursday                                        NaN
# attributes.BestNights.monday                                          NaN
# attributes.HairSpecializesIn.asian                                    NaN
# attributes.DietaryRestrictions.kosher                                 NaN
# attributes.WiFi                                                        no
# attributes.Smoking                                                    NaN
# attributes.DietaryRestrictions.halal                                  NaN
# attributes.GoodForDancing                                             NaN
# attributes.ByAppointmentOnly                                          NaN
# attributes.Caters                                                    True
# attributes.RestaurantsReservations                                  False
# attributes.DietaryRestrictions.dairy-free                             NaN
# attributes.DietaryRestrictions.vegan                                  NaN
# attributes.Ambience.romantic                                        False
# attributes.Music.jukebox                                              NaN
# attributes.Ambience.upscale                                         False
# attributes.RestaurantsTakeOut                                        True
# attributes.BikeParking                                               True
# attributes.OutdoorSeating                                           False
#
# [101 rows x 5 columns]

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==False]
NAttriBusiness=BusinessData[filter_col]
NAttriBusiness.head(20).transpose()
# Out:
#                                                0   \
# postal_code                                 44143
# hours.Thursday                        10:00-21:00
# hours.Friday                          10:00-21:00
# latitude                                  41.5417
# business_id                YDf95gJZaq05wvo7hTQbbQ
# categories       ['Shopping', 'Shopping Centers']
# name                         Richmond Town Square
# is_open                                         1
# neighborhood                                  NaN
# review_count                                   17
# state                                          OH
# address                           691 Richmond Rd
# hours.Sunday                          11:00-18:00
# hours.Wednesday                       10:00-21:00
# hours.Monday                          10:00-21:00
# city                             Richmond Heights
# hours.Tuesday                         10:00-21:00
# stars                                           2
# longitude                                -81.4931
# hours.Saturday                        10:00-21:00
#
#                                                                 1   \
# postal_code                                                  28215
# hours.Thursday                                         10:00-22:00
# hours.Friday                                           10:00-22:00
# latitude                                                   35.2369
# business_id                                 mLwM-h2YhXl2NCgdS84_Bw
# categories       ['Food', 'Soul Food', 'Convenience Stores', 'R...
# name                            South Florida Style Chicken & Ribs
# is_open                                                          0
# neighborhood                                              Eastland
# review_count                                                     4
# state                                                           NC
# address                                             2824 Milton Rd
# hours.Sunday                                           10:00-22:00
# hours.Wednesday                                        10:00-22:00
# hours.Monday                                           10:00-22:00
# city                                                     Charlotte
# hours.Tuesday                                          10:00-22:00
# stars                                                          4.5
# longitude                                                  -80.742
# hours.Saturday                                         10:00-22:00
#
#                                        2   \
# postal_code                       M4K 1N7
# hours.Thursday                10:00-19:00
# hours.Friday                  10:00-19:00
# latitude                          43.6771
# business_id        v2WhjAB3PIBA8J8VxG3wEg
# categories       ['Food', 'Coffee & Tea']
# name                     The Tea Emporium
# is_open                                 0
# neighborhood                    Riverdale
# review_count                            7
# state                                  ON
# address               337 Danforth Avenue
# hours.Sunday                  12:00-17:00
# hours.Wednesday               10:00-19:00
# hours.Monday                  10:00-19:00
# city                              Toronto
# hours.Tuesday                 10:00-19:00
# stars                                 4.5
# longitude                        -79.3533
# hours.Saturday                10:00-18:00
#
#                                                        3   \
# postal_code                                         85258
# hours.Thursday                                 9:00-17:00
# hours.Friday                                   9:00-17:00
# latitude                                          33.5651
# business_id                        CVtCbSB1zUcUWg-9TNGTuQ
# categories       ['Professional Services', 'Matchmakers']
# name                                             TRUmatch
# is_open                                                 1
# neighborhood                                          NaN
# review_count                                            3
# state                                                  AZ
# address               7702 E Doubletree Ranch Rd, Ste 300
# hours.Sunday                                          NaN
# hours.Wednesday                                9:00-17:00
# hours.Monday                                   9:00-17:00
# city                                           Scottsdale
# hours.Tuesday                                  9:00-17:00
# stars                                                   3
# longitude                                        -111.916
# hours.Saturday                                        NaN
#
#                                             4                              5   \
# postal_code                              85016                          85016
# hours.Thursday                             NaN                    10:00-20:00
# hours.Friday                               NaN                    10:00-21:00
# latitude                               33.5059                        33.5081
# business_id             duHFBe87uNSXImQmvBh87Q         uUEMrhJiL1a1pCA_I1SU7Q
# categories       ['Sandwiches', 'Restaurants']  ['Shopping', 'Tobacco Shops']
# name                                   Blimpie                Baxter's Cigars
# is_open                                      0                              0
# neighborhood                               NaN                            NaN
# review_count                                10                             35
# state                                       AZ                             AZ
# address                         4719 N 20Th St            2017 E Camelback Rd
# hours.Sunday                               NaN                    10:00-19:00
# hours.Wednesday                            NaN                    10:00-20:00
# hours.Monday                               NaN                    10:00-20:00
# city                                   Phoenix                        Phoenix
# hours.Tuesday                              NaN                    10:00-20:00
# stars                                      4.5                              5
# longitude                             -112.039                       -112.038
# hours.Saturday                             NaN                    10:00-21:00
#
#                                                     6   \
# postal_code                                      85016
# hours.Thursday                             14:00-19:00
# hours.Friday                                9:00-12:00
# latitude                                       33.5028
# business_id                     2eJEUJIP54tex7T9YOcLSw
# categories       ['Chiropractors', 'Health & Medical']
# name                          Back-Health Chiropractic
# is_open                                              1
# neighborhood                                       NaN
# review_count                                        19
# state                                               AZ
# address                        4425 N 24th St, Ste 125
# hours.Sunday                                       NaN
# hours.Wednesday                            14:30-17:00
# hours.Monday                               14:30-17:00
# city                                           Phoenix
# hours.Tuesday                              14:00-19:00
# stars                                                5
# longitude                                     -112.013
# hours.Saturday                                     NaN
#
#                                                                 7   \
# postal_code                                                  15201
# hours.Thursday                                          8:00-17:00
# hours.Friday                                            8:00-17:00
# latitude                                                   40.4859
# business_id                                 fEylCY3UEH8YJ0Xa7lu6lA
# categories       ['Automotive', 'Oil Change Stations', 'Car Was...
# name                                                 Auto Bathouse
# is_open                                                          1
# neighborhood                                         Lawrenceville
# review_count                                                    16
# state                                                           PA
# address                                             5770 Butler St
# hours.Sunday                                            8:00-16:30
# hours.Wednesday                                         8:00-17:00
# hours.Monday                                            8:00-17:00
# city                                                    Pittsburgh
# hours.Tuesday                                           8:00-17:00
# stars                                                          2.5
# longitude                                                 -79.9437
# hours.Saturday                                          8:00-17:00
#
#                                                                 8   \
# postal_code                                                  15317
# hours.Thursday                                         10:00-20:00
# hours.Friday                                           10:00-18:00
# latitude                                                   40.2905
# business_id                                 kFtuYklkAIlmYw8RZAieGw
# categories       ['Jewelry Repair', 'Gold Buyers', 'Local Servi...
# name                                           JAB Jewelry Designs
# is_open                                                          1
# neighborhood                                                   NaN
# review_count                                                     7
# state                                                           PA
# address                                         3220 Washington Rd
# hours.Sunday                                                   NaN
# hours.Wednesday                                        10:00-20:00
# hours.Monday                                           10:00-18:00
# city                                                      McMurray
# hours.Tuesday                                          10:00-18:00
# stars                                                            5
# longitude                                                   -80.11
# hours.Saturday                                         10:00-16:00
#
#                                                    9   \
# postal_code                                     85296
# hours.Thursday                             7:30-17:00
# hours.Friday                               7:30-11:00
# latitude                                      33.3245
# business_id                    NqiQdFa93wzUJGo29NbTPQ
# categories       ['Health & Medical', 'Optometrists']
# name                       Neighborhood Vision Center
# is_open                                             1
# neighborhood                                      NaN
# review_count                                        8
# state                                              AZ
# address                     1425 S Higley Rd, Ste 103
# hours.Sunday                                      NaN
# hours.Wednesday                            7:30-17:00
# hours.Monday                               7:30-17:00
# city                                          Gilbert
# hours.Tuesday                              7:30-17:00
# stars                                               5
# longitude                                     -111.72
# hours.Saturday                                    NaN
#
#                                           10  \
# postal_code                            89135
# hours.Thursday                           NaN
# hours.Friday                             NaN
# latitude                             36.1591
# business_id           N9BN9ldVl1FNzcB9_eAstw
# categories        ['Bowling', 'Active Life']
# name             Red Rock Bowling UYE Part 2
# is_open                                    1
# neighborhood                       Summerlin
# review_count                              13
# state                                     NV
# address              11022 W Charleston Blvd
# hours.Sunday                             NaN
# hours.Wednesday                          NaN
# hours.Monday                             NaN
# city                               Las Vegas
# hours.Tuesday                            NaN
# stars                                    4.5
# longitude                           -115.338
# hours.Saturday                           NaN
#
#                                                                 11  \
# postal_code                                                  85258
# hours.Thursday                                         10:00-18:00
# hours.Friday                                            9:00-19:00
# latitude                                                   33.5704
# business_id                                 6s3z3TlpHOIecuSyPEOp7A
# categories       ['Barbers', "Men's Hair Salons", 'Hair Removal...
# name                                                       Sq Cutz
# is_open                                                          0
# neighborhood                                                   NaN
# review_count                                                     7
# state                                                           AZ
# address                                    9393 N 90th St, Ste 112
# hours.Sunday                                                   NaN
# hours.Wednesday                                        10:00-18:00
# hours.Monday                                           10:00-18:00
# city                                                    Scottsdale
# hours.Tuesday                                          10:00-18:00
# stars                                                          4.5
# longitude                                                 -111.886
# hours.Saturday                                          9:00-18:00
#
#                                                                 12  \
# postal_code                                                  85209
# hours.Thursday                                           5:00-0:00
# hours.Friday                                             5:00-0:00
# latitude                                                   33.3774
# business_id                                 n33Izvzk_z9_51H6NsQF-A
# categories       ['Flowers & Gifts', 'Bakeries', 'Grocery', 'Sh...
# name                                                       Safeway
# is_open                                                          1
# neighborhood                                                   NaN
# review_count                                                    21
# state                                                           AZ
# address                                         9101 E Baseline Rd
# hours.Sunday                                             5:00-0:00
# hours.Wednesday                                          5:00-0:00
# hours.Monday                                             5:00-0:00
# city                                                          Mesa
# hours.Tuesday                                            5:00-0:00
# stars                                                            2
# longitude                                                 -111.638
# hours.Saturday                                           5:00-0:00
#
#                                                                 13  \
# postal_code                                                  85323
# hours.Thursday                                          8:00-17:00
# hours.Friday                                            8:00-17:00
# latitude                                                   33.4313
# business_id                                 m06OZRFTaKKi6U0omfLq4g
# categories       ['Landscape Architects', 'Home & Garden', 'Irr...
# name                                      Artificial Grass Masters
# is_open                                                          1
# neighborhood                                                   NaN
# review_count                                                    41
# state                                                           AZ
# address                                            12417 W Pima St
# hours.Sunday                                                   NaN
# hours.Wednesday                                         8:00-17:00
# hours.Monday                                            8:00-17:00
# city                                                      Avondale
# hours.Tuesday                                           8:00-17:00
# stars                                                          4.5
# longitude                                                 -112.326
# hours.Saturday                                          9:00-15:00
#
#                                                                 14  \
# postal_code                                                  28105
# hours.Thursday                                          11:00-0:00
# hours.Friday                                            11:00-1:00
# latitude                                                   35.1352
# business_id                                 SDMRxmcKPNt1AHPBKqO64Q
# categories       ['Burgers', 'Bars', 'Restaurants', 'Sports Bar...
# name                                                    Applebee's
# is_open                                                          1
# neighborhood                                                   NaN
# review_count                                                    21
# state                                                           NC
# address                                   9616 E Independence Blvd
# hours.Sunday                                            11:00-0:00
# hours.Wednesday                                         11:00-0:00
# hours.Monday                                            11:00-0:00
# city                                                      Matthews
# hours.Tuesday                                           11:00-0:00
# stars                                                            2
# longitude                                                 -80.7147
# hours.Saturday                                          11:00-1:00
#
#                                          15  \
# postal_code                           28164
# hours.Thursday                  11:30-22:00
# hours.Friday                    11:30-22:30
# latitude                            35.3551
# business_id          iFEiMJoEqyB9O8OUNSdLzA
# categories       ['Chinese', 'Restaurants']
# name                           China Garden
# is_open                                   1
# neighborhood                            NaN
# review_count                              3
# state                                    NC
# address                     190 E Dallas Rd
# hours.Sunday                    11:30-22:00
# hours.Wednesday                 11:30-22:00
# hours.Monday                    11:30-22:00
# city                                Stanley
# hours.Tuesday                   11:30-22:00
# stars                                     3
# longitude                          -81.0873
# hours.Saturday                  11:30-22:30
#
#                                                           16  \
# postal_code                                            85210
# hours.Thursday                                    7:00-19:00
# hours.Friday                                      7:00-19:00
# latitude                                             33.4132
# business_id                           qrAHt4wWRYWj1sEjxq574A
# categories       ['Contractors', 'Roofing', 'Home Services']
# name                                  Beach Ventures Roofing
# is_open                                                    1
# neighborhood                                             NaN
# review_count                                               3
# state                                                     AZ
# address                                             62 S Ctr
# hours.Sunday                                             NaN
# hours.Wednesday                                   7:00-19:00
# hours.Monday                                      7:00-19:00
# city                                                    Mesa
# hours.Tuesday                                     7:00-19:00
# stars                                                    3.5
# longitude                                           -111.831
# hours.Saturday                                    9:00-12:00
#
#                                                            17  \
# postal_code                                             44121
# hours.Thursday                                     8:30-18:00
# hours.Friday                                       8:30-18:00
# latitude                                              41.5018
# business_id                            jqp5TibmgJZVFKHTp3XfqQ
# categories       ['Car Wash', 'Automotive', 'Auto Detailing']
# name                                   Alpaul Automobile Wash
# is_open                                                     1
# neighborhood                                              NaN
# review_count                                               25
# state                                                      OH
# address                              2128 Warrensville Ctr Rd
# hours.Sunday                                      15:00-18:00
# hours.Wednesday                                    8:30-18:00
# hours.Monday                                       8:30-18:00
# city                                                Cleveland
# hours.Tuesday                                      8:30-18:00
# stars                                                       3
# longitude                                            -81.5368
# hours.Saturday                                     8:30-18:00
#
#                                                    18  \
# postal_code                                     44114
# hours.Thursday                             9:00-20:00
# hours.Friday                               9:00-20:00
# latitude                                      41.5094
# business_id                    1cLXGXThDYZ5WK_KpBLtkw
# categories       ['Food', 'Bakeries', 'Coffee & Tea']
# name                                      Koko Bakery
# is_open                                             1
# neighborhood                        Goodrich Kirtland
# review_count                                      162
# state                                              OH
# address                                3710 Payne Ave
# hours.Sunday                               9:00-20:00
# hours.Wednesday                            9:00-20:00
# hours.Monday                               9:00-20:00
# city                                        Cleveland
# hours.Tuesday                                     NaN
# stars                                               4
# longitude                                    -81.6622
# hours.Saturday                             9:00-20:00
#
#                                                               19
# postal_code                                                89123
# hours.Thursday                                       10:00-19:00
# hours.Friday                                         10:00-19:00
# latitude                                                 36.0404
# business_id                               BmSJ6C7Y9s3tHotRetVbmA
# categories       ['Financial Services', 'Banks & Credit Unions']
# name                                                   U.S. Bank
# is_open                                                        1
# neighborhood                                           Southeast
# review_count                                                   3
# state                                                         NV
# address                                       2385 E Windmill Ln
# hours.Sunday                                         12:00-16:00
# hours.Wednesday                                      10:00-19:00
# hours.Monday                                         10:00-19:00
# city                                                   Las Vegas
# hours.Tuesday                                        10:00-19:00
# stars                                                        3.5
# longitude                                               -115.119
# hours.Saturday                                       10:00-16:00

# %%
cols=['business_id', 'name','stars','is_open','state','city','address','postal_code','neighborhood','latitude'
                              ,'longitude','categories','hours.Monday','hours.Tuesday','hours.Wednesday','hours.Thursday','hours.Friday',
                              'hours.Saturday','hours.Sunday']

Rearrange=NAttriBusiness[cols]
Rearrange.head(20).transpose()
# Out:
#                                                0   \
# business_id                YDf95gJZaq05wvo7hTQbbQ
# name                         Richmond Town Square
# stars                                           2
# is_open                                         1
# state                                          OH
# city                             Richmond Heights
# address                           691 Richmond Rd
# postal_code                                 44143
# neighborhood                                  NaN
# latitude                                  41.5417
# longitude                                -81.4931
# categories       ['Shopping', 'Shopping Centers']
# hours.Monday                          10:00-21:00
# hours.Tuesday                         10:00-21:00
# hours.Wednesday                       10:00-21:00
# hours.Thursday                        10:00-21:00
# hours.Friday                          10:00-21:00
# hours.Saturday                        10:00-21:00
# hours.Sunday                          11:00-18:00
#
#                                                                 1   \
# business_id                                 mLwM-h2YhXl2NCgdS84_Bw
# name                            South Florida Style Chicken & Ribs
# stars                                                          4.5
# is_open                                                          0
# state                                                           NC
# city                                                     Charlotte
# address                                             2824 Milton Rd
# postal_code                                                  28215
# neighborhood                                              Eastland
# latitude                                                   35.2369
# longitude                                                  -80.742
# categories       ['Food', 'Soul Food', 'Convenience Stores', 'R...
# hours.Monday                                           10:00-22:00
# hours.Tuesday                                          10:00-22:00
# hours.Wednesday                                        10:00-22:00
# hours.Thursday                                         10:00-22:00
# hours.Friday                                           10:00-22:00
# hours.Saturday                                         10:00-22:00
# hours.Sunday                                           10:00-22:00
#
#                                        2   \
# business_id        v2WhjAB3PIBA8J8VxG3wEg
# name                     The Tea Emporium
# stars                                 4.5
# is_open                                 0
# state                                  ON
# city                              Toronto
# address               337 Danforth Avenue
# postal_code                       M4K 1N7
# neighborhood                    Riverdale
# latitude                          43.6771
# longitude                        -79.3533
# categories       ['Food', 'Coffee & Tea']
# hours.Monday                  10:00-19:00
# hours.Tuesday                 10:00-19:00
# hours.Wednesday               10:00-19:00
# hours.Thursday                10:00-19:00
# hours.Friday                  10:00-19:00
# hours.Saturday                10:00-18:00
# hours.Sunday                  12:00-17:00
#
#                                                        3   \
# business_id                        CVtCbSB1zUcUWg-9TNGTuQ
# name                                             TRUmatch
# stars                                                   3
# is_open                                                 1
# state                                                  AZ
# city                                           Scottsdale
# address               7702 E Doubletree Ranch Rd, Ste 300
# postal_code                                         85258
# neighborhood                                          NaN
# latitude                                          33.5651
# longitude                                        -111.916
# categories       ['Professional Services', 'Matchmakers']
# hours.Monday                                   9:00-17:00
# hours.Tuesday                                  9:00-17:00
# hours.Wednesday                                9:00-17:00
# hours.Thursday                                 9:00-17:00
# hours.Friday                                   9:00-17:00
# hours.Saturday                                        NaN
# hours.Sunday                                          NaN
#
#                                             4                              5   \
# business_id             duHFBe87uNSXImQmvBh87Q         uUEMrhJiL1a1pCA_I1SU7Q
# name                                   Blimpie                Baxter's Cigars
# stars                                      4.5                              5
# is_open                                      0                              0
# state                                       AZ                             AZ
# city                                   Phoenix                        Phoenix
# address                         4719 N 20Th St            2017 E Camelback Rd
# postal_code                              85016                          85016
# neighborhood                               NaN                            NaN
# latitude                               33.5059                        33.5081
# longitude                             -112.039                       -112.038
# categories       ['Sandwiches', 'Restaurants']  ['Shopping', 'Tobacco Shops']
# hours.Monday                               NaN                    10:00-20:00
# hours.Tuesday                              NaN                    10:00-20:00
# hours.Wednesday                            NaN                    10:00-20:00
# hours.Thursday                             NaN                    10:00-20:00
# hours.Friday                               NaN                    10:00-21:00
# hours.Saturday                             NaN                    10:00-21:00
# hours.Sunday                               NaN                    10:00-19:00
#
#                                                     6   \
# business_id                     2eJEUJIP54tex7T9YOcLSw
# name                          Back-Health Chiropractic
# stars                                                5
# is_open                                              1
# state                                               AZ
# city                                           Phoenix
# address                        4425 N 24th St, Ste 125
# postal_code                                      85016
# neighborhood                                       NaN
# latitude                                       33.5028
# longitude                                     -112.013
# categories       ['Chiropractors', 'Health & Medical']
# hours.Monday                               14:30-17:00
# hours.Tuesday                              14:00-19:00
# hours.Wednesday                            14:30-17:00
# hours.Thursday                             14:00-19:00
# hours.Friday                                9:00-12:00
# hours.Saturday                                     NaN
# hours.Sunday                                       NaN
#
#                                                                 7   \
# business_id                                 fEylCY3UEH8YJ0Xa7lu6lA
# name                                                 Auto Bathouse
# stars                                                          2.5
# is_open                                                          1
# state                                                           PA
# city                                                    Pittsburgh
# address                                             5770 Butler St
# postal_code                                                  15201
# neighborhood                                         Lawrenceville
# latitude                                                   40.4859
# longitude                                                 -79.9437
# categories       ['Automotive', 'Oil Change Stations', 'Car Was...
# hours.Monday                                            8:00-17:00
# hours.Tuesday                                           8:00-17:00
# hours.Wednesday                                         8:00-17:00
# hours.Thursday                                          8:00-17:00
# hours.Friday                                            8:00-17:00
# hours.Saturday                                          8:00-17:00
# hours.Sunday                                            8:00-16:30
#
#                                                                 8   \
# business_id                                 kFtuYklkAIlmYw8RZAieGw
# name                                           JAB Jewelry Designs
# stars                                                            5
# is_open                                                          1
# state                                                           PA
# city                                                      McMurray
# address                                         3220 Washington Rd
# postal_code                                                  15317
# neighborhood                                                   NaN
# latitude                                                   40.2905
# longitude                                                   -80.11
# categories       ['Jewelry Repair', 'Gold Buyers', 'Local Servi...
# hours.Monday                                           10:00-18:00
# hours.Tuesday                                          10:00-18:00
# hours.Wednesday                                        10:00-20:00
# hours.Thursday                                         10:00-20:00
# hours.Friday                                           10:00-18:00
# hours.Saturday                                         10:00-16:00
# hours.Sunday                                                   NaN
#
#                                                    9   \
# business_id                    NqiQdFa93wzUJGo29NbTPQ
# name                       Neighborhood Vision Center
# stars                                               5
# is_open                                             1
# state                                              AZ
# city                                          Gilbert
# address                     1425 S Higley Rd, Ste 103
# postal_code                                     85296
# neighborhood                                      NaN
# latitude                                      33.3245
# longitude                                     -111.72
# categories       ['Health & Medical', 'Optometrists']
# hours.Monday                               7:30-17:00
# hours.Tuesday                              7:30-17:00
# hours.Wednesday                            7:30-17:00
# hours.Thursday                             7:30-17:00
# hours.Friday                               7:30-11:00
# hours.Saturday                                    NaN
# hours.Sunday                                      NaN
#
#                                           10  \
# business_id           N9BN9ldVl1FNzcB9_eAstw
# name             Red Rock Bowling UYE Part 2
# stars                                    4.5
# is_open                                    1
# state                                     NV
# city                               Las Vegas
# address              11022 W Charleston Blvd
# postal_code                            89135
# neighborhood                       Summerlin
# latitude                             36.1591
# longitude                           -115.338
# categories        ['Bowling', 'Active Life']
# hours.Monday                             NaN
# hours.Tuesday                            NaN
# hours.Wednesday                          NaN
# hours.Thursday                           NaN
# hours.Friday                             NaN
# hours.Saturday                           NaN
# hours.Sunday                             NaN
#
#                                                                 11  \
# business_id                                 6s3z3TlpHOIecuSyPEOp7A
# name                                                       Sq Cutz
# stars                                                          4.5
# is_open                                                          0
# state                                                           AZ
# city                                                    Scottsdale
# address                                    9393 N 90th St, Ste 112
# postal_code                                                  85258
# neighborhood                                                   NaN
# latitude                                                   33.5704
# longitude                                                 -111.886
# categories       ['Barbers', "Men's Hair Salons", 'Hair Removal...
# hours.Monday                                           10:00-18:00
# hours.Tuesday                                          10:00-18:00
# hours.Wednesday                                        10:00-18:00
# hours.Thursday                                         10:00-18:00
# hours.Friday                                            9:00-19:00
# hours.Saturday                                          9:00-18:00
# hours.Sunday                                                   NaN
#
#                                                                 12  \
# business_id                                 n33Izvzk_z9_51H6NsQF-A
# name                                                       Safeway
# stars                                                            2
# is_open                                                          1
# state                                                           AZ
# city                                                          Mesa
# address                                         9101 E Baseline Rd
# postal_code                                                  85209
# neighborhood                                                   NaN
# latitude                                                   33.3774
# longitude                                                 -111.638
# categories       ['Flowers & Gifts', 'Bakeries', 'Grocery', 'Sh...
# hours.Monday                                             5:00-0:00
# hours.Tuesday                                            5:00-0:00
# hours.Wednesday                                          5:00-0:00
# hours.Thursday                                           5:00-0:00
# hours.Friday                                             5:00-0:00
# hours.Saturday                                           5:00-0:00
# hours.Sunday                                             5:00-0:00
#
#                                                                 13  \
# business_id                                 m06OZRFTaKKi6U0omfLq4g
# name                                      Artificial Grass Masters
# stars                                                          4.5
# is_open                                                          1
# state                                                           AZ
# city                                                      Avondale
# address                                            12417 W Pima St
# postal_code                                                  85323
# neighborhood                                                   NaN
# latitude                                                   33.4313
# longitude                                                 -112.326
# categories       ['Landscape Architects', 'Home & Garden', 'Irr...
# hours.Monday                                            8:00-17:00
# hours.Tuesday                                           8:00-17:00
# hours.Wednesday                                         8:00-17:00
# hours.Thursday                                          8:00-17:00
# hours.Friday                                            8:00-17:00
# hours.Saturday                                          9:00-15:00
# hours.Sunday                                                   NaN
#
#                                                                 14  \
# business_id                                 SDMRxmcKPNt1AHPBKqO64Q
# name                                                    Applebee's
# stars                                                            2
# is_open                                                          1
# state                                                           NC
# city                                                      Matthews
# address                                   9616 E Independence Blvd
# postal_code                                                  28105
# neighborhood                                                   NaN
# latitude                                                   35.1352
# longitude                                                 -80.7147
# categories       ['Burgers', 'Bars', 'Restaurants', 'Sports Bar...
# hours.Monday                                            11:00-0:00
# hours.Tuesday                                           11:00-0:00
# hours.Wednesday                                         11:00-0:00
# hours.Thursday                                          11:00-0:00
# hours.Friday                                            11:00-1:00
# hours.Saturday                                          11:00-1:00
# hours.Sunday                                            11:00-0:00
#
#                                          15  \
# business_id          iFEiMJoEqyB9O8OUNSdLzA
# name                           China Garden
# stars                                     3
# is_open                                   1
# state                                    NC
# city                                Stanley
# address                     190 E Dallas Rd
# postal_code                           28164
# neighborhood                            NaN
# latitude                            35.3551
# longitude                          -81.0873
# categories       ['Chinese', 'Restaurants']
# hours.Monday                    11:30-22:00
# hours.Tuesday                   11:30-22:00
# hours.Wednesday                 11:30-22:00
# hours.Thursday                  11:30-22:00
# hours.Friday                    11:30-22:30
# hours.Saturday                  11:30-22:30
# hours.Sunday                    11:30-22:00
#
#                                                           16  \
# business_id                           qrAHt4wWRYWj1sEjxq574A
# name                                  Beach Ventures Roofing
# stars                                                    3.5
# is_open                                                    1
# state                                                     AZ
# city                                                    Mesa
# address                                             62 S Ctr
# postal_code                                            85210
# neighborhood                                             NaN
# latitude                                             33.4132
# longitude                                           -111.831
# categories       ['Contractors', 'Roofing', 'Home Services']
# hours.Monday                                      7:00-19:00
# hours.Tuesday                                     7:00-19:00
# hours.Wednesday                                   7:00-19:00
# hours.Thursday                                    7:00-19:00
# hours.Friday                                      7:00-19:00
# hours.Saturday                                    9:00-12:00
# hours.Sunday                                             NaN
#
#                                                            17  \
# business_id                            jqp5TibmgJZVFKHTp3XfqQ
# name                                   Alpaul Automobile Wash
# stars                                                       3
# is_open                                                     1
# state                                                      OH
# city                                                Cleveland
# address                              2128 Warrensville Ctr Rd
# postal_code                                             44121
# neighborhood                                              NaN
# latitude                                              41.5018
# longitude                                            -81.5368
# categories       ['Car Wash', 'Automotive', 'Auto Detailing']
# hours.Monday                                       8:30-18:00
# hours.Tuesday                                      8:30-18:00
# hours.Wednesday                                    8:30-18:00
# hours.Thursday                                     8:30-18:00
# hours.Friday                                       8:30-18:00
# hours.Saturday                                     8:30-18:00
# hours.Sunday                                      15:00-18:00
#
#                                                    18  \
# business_id                    1cLXGXThDYZ5WK_KpBLtkw
# name                                      Koko Bakery
# stars                                               4
# is_open                                             1
# state                                              OH
# city                                        Cleveland
# address                                3710 Payne Ave
# postal_code                                     44114
# neighborhood                        Goodrich Kirtland
# latitude                                      41.5094
# longitude                                    -81.6622
# categories       ['Food', 'Bakeries', 'Coffee & Tea']
# hours.Monday                               9:00-20:00
# hours.Tuesday                                     NaN
# hours.Wednesday                            9:00-20:00
# hours.Thursday                             9:00-20:00
# hours.Friday                               9:00-20:00
# hours.Saturday                             9:00-20:00
# hours.Sunday                               9:00-20:00
#
#                                                               19
# business_id                               BmSJ6C7Y9s3tHotRetVbmA
# name                                                   U.S. Bank
# stars                                                        3.5
# is_open                                                        1
# state                                                         NV
# city                                                   Las Vegas
# address                                       2385 E Windmill Ln
# postal_code                                                89123
# neighborhood                                           Southeast
# latitude                                                 36.0404
# longitude                                               -115.119
# categories       ['Financial Services', 'Banks & Credit Unions']
# hours.Monday                                         10:00-19:00
# hours.Tuesday                                        10:00-19:00
# hours.Wednesday                                      10:00-19:00
# hours.Thursday                                       10:00-19:00
# hours.Friday                                         10:00-19:00
# hours.Saturday                                       10:00-16:00
# hours.Sunday                                         12:00-16:00

# %%
filter_col = [col for col in BusinessData if col.startswith('attributes.')==True]
AttriBusiness=BusinessData[filter_col]
AttriBusiness.head(20).transpose()
# Out:
#                                                0        1      2    3      4   \
# attributes.Ambience.divey                     NaN    False    NaN  NaN  False
# attributes.RestaurantsDelivery                NaN     True    NaN  NaN  False
# attributes.DogsAllowed                        NaN      NaN    NaN  NaN    NaN
# attributes.HairSpecializesIn.coloring         NaN      NaN    NaN  NaN    NaN
# attributes.BestNights.sunday                  NaN      NaN    NaN  NaN    NaN
# attributes.BYOB                               NaN      NaN    NaN  NaN    NaN
# attributes.AgesAllowed                        NaN      NaN    NaN  NaN    NaN
# attributes.Music.video                        NaN      NaN    NaN  NaN    NaN
# attributes.Alcohol                            NaN      NaN    NaN  NaN   none
# attributes.Ambience.classy                    NaN    False    NaN  NaN  False
# attributes.RestaurantsTableService            NaN      NaN    NaN  NaN  False
# attributes.Ambience.touristy                  NaN    False    NaN  NaN  False
# attributes.RestaurantsCounterService          NaN      NaN    NaN  NaN    NaN
# attributes.Corkage                            NaN      NaN    NaN  NaN    NaN
# attributes.RestaurantsGoodForGroups           NaN     True    NaN  NaN   True
# attributes.BusinessAcceptsBitcoin             NaN      NaN    NaN  NaN    NaN
# attributes.HappyHour                          NaN      NaN    NaN  NaN    NaN
# attributes.WheelchairAccessible              True      NaN   True  NaN    NaN
# attributes.Ambience.hipster                   NaN    False    NaN  NaN  False
# attributes.BusinessAcceptsCreditCards         NaN    False   True  NaN   True
# attributes.DietaryRestrictions.vegetarian     NaN      NaN    NaN  NaN    NaN
# attributes.Music.live                         NaN      NaN    NaN  NaN    NaN
# attributes.Music.background_music             NaN      NaN    NaN  NaN    NaN
# attributes.BusinessParking.lot               True      NaN  False  NaN  False
# attributes.Music.karaoke                      NaN      NaN    NaN  NaN    NaN
# attributes.GoodForMeal.breakfast              NaN    False    NaN  NaN  False
# attributes.NoiseLevel                         NaN  average    NaN  NaN  quiet
# attributes.HairSpecializesIn.perms            NaN      NaN    NaN  NaN    NaN
# attributes.DriveThru                          NaN      NaN    NaN  NaN    NaN
# attributes.HasTV                              NaN    False    NaN  NaN  False
# ...                                           ...      ...    ...  ...    ...
# attributes.DietaryRestrictions.soy-free       NaN      NaN    NaN  NaN    NaN
# attributes.GoodForMeal.brunch                 NaN    False    NaN  NaN  False
# attributes.BusinessParking.valet            False      NaN  False  NaN  False
# attributes.DietaryRestrictions.gluten-free    NaN      NaN    NaN  NaN    NaN
# attributes.BYOBCorkage                        NaN      NaN    NaN  NaN    NaN
# attributes.BusinessParking.garage           False      NaN  False  NaN  False
# attributes.BestNights.friday                  NaN      NaN    NaN  NaN    NaN
# attributes.Music.dj                           NaN      NaN    NaN  NaN    NaN
# attributes.HairSpecializesIn.extensions       NaN      NaN    NaN  NaN    NaN
# attributes.BestNights.saturday                NaN      NaN    NaN  NaN    NaN
# attributes.Ambience.casual                    NaN    False    NaN  NaN  False
# attributes.BestNights.thursday                NaN      NaN    NaN  NaN    NaN
# attributes.BestNights.monday                  NaN      NaN    NaN  NaN    NaN
# attributes.HairSpecializesIn.asian            NaN      NaN    NaN  NaN    NaN
# attributes.DietaryRestrictions.kosher         NaN      NaN    NaN  NaN    NaN
# attributes.WiFi                               NaN      NaN     no  NaN     no
# attributes.Smoking                            NaN      NaN    NaN  NaN    NaN
# attributes.DietaryRestrictions.halal          NaN      NaN    NaN  NaN    NaN
# attributes.GoodForDancing                     NaN      NaN    NaN  NaN    NaN
# attributes.ByAppointmentOnly                  NaN      NaN    NaN  NaN    NaN
# attributes.Caters                             NaN      NaN    NaN  NaN   True
# attributes.RestaurantsReservations            NaN    False    NaN  NaN  False
# attributes.DietaryRestrictions.dairy-free     NaN      NaN    NaN  NaN    NaN
# attributes.DietaryRestrictions.vegan          NaN      NaN    NaN  NaN    NaN
# attributes.Ambience.romantic                  NaN    False    NaN  NaN  False
# attributes.Music.jukebox                      NaN      NaN    NaN  NaN    NaN
# attributes.Ambience.upscale                   NaN    False    NaN  NaN  False
# attributes.RestaurantsTakeOut                 NaN     True    NaN  NaN   True
# attributes.BikeParking                       True      NaN   True  NaN   True
# attributes.OutdoorSeating                     NaN    False  False  NaN  False
#
#                                                5     6     7      8     9   \
# attributes.Ambience.divey                     NaN   NaN   NaN    NaN   NaN
# attributes.RestaurantsDelivery                NaN   NaN   NaN    NaN   NaN
# attributes.DogsAllowed                        NaN   NaN   NaN   True   NaN
# attributes.HairSpecializesIn.coloring         NaN   NaN   NaN    NaN   NaN
# attributes.BestNights.sunday                  NaN   NaN   NaN    NaN   NaN
# attributes.BYOB                               NaN   NaN   NaN    NaN   NaN
# attributes.AgesAllowed                        NaN   NaN   NaN    NaN   NaN
# attributes.Music.video                        NaN   NaN   NaN    NaN   NaN
# attributes.Alcohol                            NaN   NaN   NaN    NaN   NaN
# attributes.Ambience.classy                    NaN   NaN   NaN    NaN   NaN
# attributes.RestaurantsTableService            NaN   NaN   NaN    NaN   NaN
# attributes.Ambience.touristy                  NaN   NaN   NaN    NaN   NaN
# attributes.RestaurantsCounterService          NaN   NaN   NaN    NaN   NaN
# attributes.Corkage                            NaN   NaN   NaN    NaN   NaN
# attributes.RestaurantsGoodForGroups           NaN   NaN   NaN    NaN   NaN
# attributes.BusinessAcceptsBitcoin             NaN   NaN   NaN    NaN   NaN
# attributes.HappyHour                          NaN   NaN   NaN    NaN   NaN
# attributes.WheelchairAccessible               NaN   NaN   NaN   True   NaN
# attributes.Ambience.hipster                   NaN   NaN   NaN    NaN   NaN
# attributes.BusinessAcceptsCreditCards        True  True  True   True  True
# attributes.DietaryRestrictions.vegetarian     NaN   NaN   NaN    NaN   NaN
# attributes.Music.live                         NaN   NaN   NaN    NaN   NaN
# attributes.Music.background_music             NaN   NaN   NaN    NaN   NaN
# attributes.BusinessParking.lot               True   NaN   NaN   True   NaN
# attributes.Music.karaoke                      NaN   NaN   NaN    NaN   NaN
# attributes.GoodForMeal.breakfast              NaN   NaN   NaN    NaN   NaN
# attributes.NoiseLevel                         NaN   NaN   NaN    NaN   NaN
# attributes.HairSpecializesIn.perms            NaN   NaN   NaN    NaN   NaN
# attributes.DriveThru                          NaN   NaN   NaN    NaN   NaN
# attributes.HasTV                              NaN   NaN   NaN    NaN   NaN
# ...                                           ...   ...   ...    ...   ...
# attributes.DietaryRestrictions.soy-free       NaN   NaN   NaN    NaN   NaN
# attributes.GoodForMeal.brunch                 NaN   NaN   NaN    NaN   NaN
# attributes.BusinessParking.valet            False   NaN   NaN  False   NaN
# attributes.DietaryRestrictions.gluten-free    NaN   NaN   NaN    NaN   NaN
# attributes.BYOBCorkage                        NaN   NaN   NaN    NaN   NaN
# attributes.BusinessParking.garage           False   NaN   NaN  False   NaN
# attributes.BestNights.friday                  NaN   NaN   NaN    NaN   NaN
# attributes.Music.dj                           NaN   NaN   NaN    NaN   NaN
# attributes.HairSpecializesIn.extensions       NaN   NaN   NaN    NaN   NaN
# attributes.BestNights.saturday                NaN   NaN   NaN    NaN   NaN
# attributes.Ambience.casual                    NaN   NaN   NaN    NaN   NaN
# attributes.BestNights.thursday                NaN   NaN   NaN    NaN   NaN
# attributes.BestNights.monday                  NaN   NaN   NaN    NaN   NaN
# attributes.HairSpecializesIn.asian            NaN   NaN   NaN    NaN   NaN
# attributes.DietaryRestrictions.kosher         NaN   NaN   NaN    NaN   NaN
# attributes.WiFi                               NaN   NaN   NaN    NaN   NaN
# attributes.Smoking                            NaN   NaN   NaN    NaN   NaN
# attributes.DietaryRestrictions.halal          NaN   NaN   NaN    NaN   NaN
# attributes.GoodForDancing                     NaN   NaN   NaN    NaN   NaN
# attributes.ByAppointmentOnly                  NaN  True   NaN  False  True
# attributes.Caters                             NaN   NaN   NaN    NaN   NaN
# attributes.RestaurantsReservations            NaN   NaN   NaN    NaN   NaN
# attributes.DietaryRestrictions.dairy-free     NaN   NaN   NaN    NaN   NaN
# attributes.DietaryRestrictions.vegan          NaN   NaN   NaN    NaN   NaN
# attributes.Ambience.romantic                  NaN   NaN   NaN    NaN   NaN
# attributes.Music.jukebox                      NaN   NaN   NaN    NaN   NaN
# attributes.Ambience.upscale                   NaN   NaN   NaN    NaN   NaN
# attributes.RestaurantsTakeOut                 NaN   NaN   NaN    NaN   NaN
# attributes.BikeParking                       True   NaN   NaN   True   NaN
# attributes.OutdoorSeating                     NaN   NaN   NaN    NaN   NaN
#
#                                                10     11     12     13  \
# attributes.Ambience.divey                     NaN    NaN    NaN    NaN
# attributes.RestaurantsDelivery                NaN    NaN  False    NaN
# attributes.DogsAllowed                        NaN    NaN    NaN    NaN
# attributes.HairSpecializesIn.coloring         NaN  False    NaN    NaN
# attributes.BestNights.sunday                  NaN    NaN    NaN    NaN
# attributes.BYOB                               NaN    NaN    NaN    NaN
# attributes.AgesAllowed                        NaN    NaN    NaN    NaN
# attributes.Music.video                        NaN    NaN    NaN    NaN
# attributes.Alcohol                            NaN    NaN    NaN    NaN
# attributes.Ambience.classy                    NaN    NaN    NaN    NaN
# attributes.RestaurantsTableService            NaN    NaN    NaN    NaN
# attributes.Ambience.touristy                  NaN    NaN    NaN    NaN
# attributes.RestaurantsCounterService          NaN    NaN    NaN    NaN
# attributes.Corkage                            NaN    NaN    NaN    NaN
# attributes.RestaurantsGoodForGroups           NaN    NaN    NaN    NaN
# attributes.BusinessAcceptsBitcoin             NaN    NaN    NaN  False
# attributes.HappyHour                          NaN    NaN    NaN    NaN
# attributes.WheelchairAccessible               NaN   True    NaN    NaN
# attributes.Ambience.hipster                   NaN    NaN    NaN    NaN
# attributes.BusinessAcceptsCreditCards        True   True   True   True
# attributes.DietaryRestrictions.vegetarian     NaN    NaN    NaN    NaN
# attributes.Music.live                         NaN    NaN    NaN    NaN
# attributes.Music.background_music             NaN    NaN    NaN    NaN
# attributes.BusinessParking.lot              False   True   True    NaN
# attributes.Music.karaoke                      NaN    NaN    NaN    NaN
# attributes.GoodForMeal.breakfast              NaN    NaN    NaN    NaN
# attributes.NoiseLevel                         NaN    NaN    NaN    NaN
# attributes.HairSpecializesIn.perms            NaN  False    NaN    NaN
# attributes.DriveThru                          NaN    NaN    NaN    NaN
# attributes.HasTV                              NaN    NaN    NaN    NaN
# ...                                           ...    ...    ...    ...
# attributes.DietaryRestrictions.soy-free       NaN    NaN    NaN    NaN
# attributes.GoodForMeal.brunch                 NaN    NaN    NaN    NaN
# attributes.BusinessParking.valet            False  False  False    NaN
# attributes.DietaryRestrictions.gluten-free    NaN    NaN    NaN    NaN
# attributes.BYOBCorkage                        NaN    NaN    NaN    NaN
# attributes.BusinessParking.garage            True  False  False    NaN
# attributes.BestNights.friday                  NaN    NaN    NaN    NaN
# attributes.Music.dj                           NaN    NaN    NaN    NaN
# attributes.HairSpecializesIn.extensions       NaN  False    NaN    NaN
# attributes.BestNights.saturday                NaN    NaN    NaN    NaN
# attributes.Ambience.casual                    NaN    NaN    NaN    NaN
# attributes.BestNights.thursday                NaN    NaN    NaN    NaN
# attributes.BestNights.monday                  NaN    NaN    NaN    NaN
# attributes.HairSpecializesIn.asian            NaN  False    NaN    NaN
# attributes.DietaryRestrictions.kosher         NaN    NaN    NaN    NaN
# attributes.WiFi                               NaN    NaN    NaN    NaN
# attributes.Smoking                            NaN    NaN    NaN    NaN
# attributes.DietaryRestrictions.halal          NaN    NaN    NaN    NaN
# attributes.GoodForDancing                     NaN    NaN    NaN    NaN
# attributes.ByAppointmentOnly                  NaN  False    NaN   True
# attributes.Caters                             NaN    NaN   True    NaN
# attributes.RestaurantsReservations            NaN    NaN    NaN    NaN
# attributes.DietaryRestrictions.dairy-free     NaN    NaN    NaN    NaN
# attributes.DietaryRestrictions.vegan          NaN    NaN    NaN    NaN
# attributes.Ambience.romantic                  NaN    NaN    NaN    NaN
# attributes.Music.jukebox                      NaN    NaN    NaN    NaN
# attributes.Ambience.upscale                   NaN    NaN    NaN    NaN
# attributes.RestaurantsTakeOut                 NaN    NaN   True    NaN
# attributes.BikeParking                       True   True   True    NaN
# attributes.OutdoorSeating                     NaN    NaN    NaN    NaN
#
#                                                   14     15    16    17  \
# attributes.Ambience.divey                      False    NaN   NaN   NaN
# attributes.RestaurantsDelivery                 False    NaN   NaN   NaN
# attributes.DogsAllowed                           NaN    NaN   NaN   NaN
# attributes.HairSpecializesIn.coloring            NaN    NaN   NaN   NaN
# attributes.BestNights.sunday                     NaN    NaN   NaN   NaN
# attributes.BYOB                                  NaN    NaN   NaN   NaN
# attributes.AgesAllowed                           NaN    NaN   NaN   NaN
# attributes.Music.video                         False    NaN   NaN   NaN
# attributes.Alcohol                          full_bar   none   NaN   NaN
# attributes.Ambience.classy                     False    NaN   NaN   NaN
# attributes.RestaurantsTableService             False    NaN   NaN   NaN
# attributes.Ambience.touristy                   False    NaN   NaN   NaN
# attributes.RestaurantsCounterService             NaN    NaN   NaN   NaN
# attributes.Corkage                               NaN    NaN   NaN   NaN
# attributes.RestaurantsGoodForGroups             True    NaN   NaN   NaN
# attributes.BusinessAcceptsBitcoin                NaN    NaN   NaN   NaN
# attributes.HappyHour                            True    NaN   NaN   NaN
# attributes.WheelchairAccessible                  NaN    NaN   NaN   NaN
# attributes.Ambience.hipster                    False    NaN   NaN   NaN
# attributes.BusinessAcceptsCreditCards           True    NaN  True  True
# attributes.DietaryRestrictions.vegetarian        NaN    NaN   NaN   NaN
# attributes.Music.live                          False    NaN   NaN   NaN
# attributes.Music.background_music              False    NaN   NaN   NaN
# attributes.BusinessParking.lot                 False    NaN   NaN   NaN
# attributes.Music.karaoke                       False    NaN   NaN   NaN
# attributes.GoodForMeal.breakfast               False    NaN   NaN   NaN
# attributes.NoiseLevel                        average    NaN   NaN   NaN
# attributes.HairSpecializesIn.perms               NaN    NaN   NaN   NaN
# attributes.DriveThru                           False    NaN   NaN   NaN
# attributes.HasTV                                True    NaN   NaN   NaN
# ...                                              ...    ...   ...   ...
# attributes.DietaryRestrictions.soy-free          NaN    NaN   NaN   NaN
# attributes.GoodForMeal.brunch                  False    NaN   NaN   NaN
# attributes.BusinessParking.valet               False    NaN   NaN   NaN
# attributes.DietaryRestrictions.gluten-free       NaN    NaN   NaN   NaN
# attributes.BYOBCorkage                           NaN    NaN   NaN   NaN
# attributes.BusinessParking.garage              False    NaN   NaN   NaN
# attributes.BestNights.friday                     NaN    NaN   NaN   NaN
# attributes.Music.dj                            False    NaN   NaN   NaN
# attributes.HairSpecializesIn.extensions          NaN    NaN   NaN   NaN
# attributes.BestNights.saturday                   NaN    NaN   NaN   NaN
# attributes.Ambience.casual                     False    NaN   NaN   NaN
# attributes.BestNights.thursday                   NaN    NaN   NaN   NaN
# attributes.BestNights.monday                     NaN    NaN   NaN   NaN
# attributes.HairSpecializesIn.asian               NaN    NaN   NaN   NaN
# attributes.DietaryRestrictions.kosher            NaN    NaN   NaN   NaN
# attributes.WiFi                                 free    NaN   NaN   NaN
# attributes.Smoking                               NaN    NaN   NaN   NaN
# attributes.DietaryRestrictions.halal             NaN    NaN   NaN   NaN
# attributes.GoodForDancing                      False    NaN   NaN   NaN
# attributes.ByAppointmentOnly                     NaN    NaN  True   NaN
# attributes.Caters                              False    NaN   NaN   NaN
# attributes.RestaurantsReservations             False    NaN   NaN   NaN
# attributes.DietaryRestrictions.dairy-free        NaN    NaN   NaN   NaN
# attributes.DietaryRestrictions.vegan             NaN    NaN   NaN   NaN
# attributes.Ambience.romantic                   False    NaN   NaN   NaN
# attributes.Music.jukebox                       False    NaN   NaN   NaN
# attributes.Ambience.upscale                    False    NaN   NaN   NaN
# attributes.RestaurantsTakeOut                   True    NaN   NaN   NaN
# attributes.BikeParking                          True    NaN   NaN   NaN
# attributes.OutdoorSeating                      False  False   NaN   NaN
#
#                                                18   19
# attributes.Ambience.divey                     NaN  NaN
# attributes.RestaurantsDelivery              False  NaN
# attributes.DogsAllowed                        NaN  NaN
# attributes.HairSpecializesIn.coloring         NaN  NaN
# attributes.BestNights.sunday                  NaN  NaN
# attributes.BYOB                               NaN  NaN
# attributes.AgesAllowed                        NaN  NaN
# attributes.Music.video                        NaN  NaN
# attributes.Alcohol                            NaN  NaN
# attributes.Ambience.classy                    NaN  NaN
# attributes.RestaurantsTableService            NaN  NaN
# attributes.Ambience.touristy                  NaN  NaN
# attributes.RestaurantsCounterService          NaN  NaN
# attributes.Corkage                            NaN  NaN
# attributes.RestaurantsGoodForGroups           NaN  NaN
# attributes.BusinessAcceptsBitcoin             NaN  NaN
# attributes.HappyHour                          NaN  NaN
# attributes.WheelchairAccessible              True  NaN
# attributes.Ambience.hipster                   NaN  NaN
# attributes.BusinessAcceptsCreditCards        True  NaN
# attributes.DietaryRestrictions.vegetarian     NaN  NaN
# attributes.Music.live                         NaN  NaN
# attributes.Music.background_music             NaN  NaN
# attributes.BusinessParking.lot               True  NaN
# attributes.Music.karaoke                      NaN  NaN
# attributes.GoodForMeal.breakfast              NaN  NaN
# attributes.NoiseLevel                         NaN  NaN
# attributes.HairSpecializesIn.perms            NaN  NaN
# attributes.DriveThru                          NaN  NaN
# attributes.HasTV                              NaN  NaN
# ...                                           ...  ...
# attributes.DietaryRestrictions.soy-free       NaN  NaN
# attributes.GoodForMeal.brunch                 NaN  NaN
# attributes.BusinessParking.valet            False  NaN
# attributes.DietaryRestrictions.gluten-free    NaN  NaN
# attributes.BYOBCorkage                        NaN  NaN
# attributes.BusinessParking.garage           False  NaN
# attributes.BestNights.friday                  NaN  NaN
# attributes.Music.dj                           NaN  NaN
# attributes.HairSpecializesIn.extensions       NaN  NaN
# attributes.BestNights.saturday                NaN  NaN
# attributes.Ambience.casual                    NaN  NaN
# attributes.BestNights.thursday                NaN  NaN
# attributes.BestNights.monday                  NaN  NaN
# attributes.HairSpecializesIn.asian            NaN  NaN
# attributes.DietaryRestrictions.kosher         NaN  NaN
# attributes.WiFi                              free  NaN
# attributes.Smoking                            NaN  NaN
# attributes.DietaryRestrictions.halal          NaN  NaN
# attributes.GoodForDancing                     NaN  NaN
# attributes.ByAppointmentOnly                  NaN  NaN
# attributes.Caters                            True  NaN
# attributes.RestaurantsReservations            NaN  NaN
# attributes.DietaryRestrictions.dairy-free     NaN  NaN
# attributes.DietaryRestrictions.vegan          NaN  NaN
# attributes.Ambience.romantic                  NaN  NaN
# attributes.Music.jukebox                      NaN  NaN
# attributes.Ambience.upscale                   NaN  NaN
# attributes.RestaurantsTakeOut                True  NaN
# attributes.BikeParking                       True  NaN
# attributes.OutdoorSeating                   False  NaN
#
# [81 rows x 20 columns]

# %%
NAttriBusiness.describe().transpose()
# Out:
#                  count       mean        std         min         25%  \
# latitude      156638.0  38.585033   5.399871  -36.086009   33.627161
# is_open       156639.0   0.844375   0.362501    0.000000    1.000000
# review_count  156639.0  30.238159  96.486631    3.000000    4.000000
# stars         156639.0   3.647154   0.977640    1.000000    3.000000
# longitude     156638.0 -92.856485  26.557741 -142.466650 -112.138207
#
#                     50%        75%          max
# latitude      36.142381  43.596845    89.999314
# is_open        1.000000   1.000000     1.000000
# review_count   9.000000  23.000000  6979.000000
# stars          3.500000   4.500000     5.000000
# longitude    -89.523198 -79.668760   115.086769

# %%
plt.figure()
hist_inc = NAttriBusiness['stars'].hist()
plt.title('Histogram of Review Stars')
plt.show()

# %%
plt.scatter(NAttriBusiness['stars'], NAttriBusiness['review_count'])
plt.show()

# %%
NAttriBusiness.to_csv('buwithoutattribute.csv')
